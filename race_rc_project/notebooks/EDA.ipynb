# %% [markdown]
# # 📊 NeuraQuiz AI: Exploratory Data Analysis (EDA)
#
# This notebook provides a summary of the RACE dataset distribution and exploratory data analysis.
# All plots have been pre-computed by the preprocessing pipeline and are saved in `results/eda/`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display
import os

# Load Summary Statistics
stats_df = pd.read_csv('../results/eda/summary_statistics.csv')
display(stats_df)

# %% [markdown]
# ## Visualizations
# The following charts show the distribution of article lengths, option lengths, and answer balances.

# %%
eda_dir = '../results/eda/'
images = [
    'answer_distribution.png',
    'article_length_dist.png',
    'option_length_dist.png',
    'question_length_dist.png',
    'question_type_dist.png',
    'top_tfidf_terms.png'
]

for img in images:
    img_path = os.path.join(eda_dir, img)
    if os.path.exists(img_path):
        print(f"Displaying: {img}")
        display(Image(filename=img_path))
    else:
        print(f"Image not found: {img}")
